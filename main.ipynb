# %% [markdown]
# ## This "main.ipynb" is a copy of main.py. just for showing all possible Usabilities for user.

# %%
def main():
    print("\n\nWelcom to Personalized Book Search Engine\n\n")


    import warnings
    import SearchEngine as SE
    warnings.filterwarnings("ignore")
    import csv
    import os
    import pandas as pd

    decision = input("Enter 1 if you want to proceed to Book Search to find similar books\nEnter 2 if you want to continue with books in your wishlist/to_read \n")
    if(decision =='1'):
        search_eng = SE.SearchEngine()
        user_id = int(input("Enter User_Id between 0-53424\n")) # 0-53424
        query = input("Enter your text/query to find similar recommadtions to it.\n")
        save_res =True
        boosting_factor = float(input("Enter to_read_boosting_factor ? :\n"))
        top_recommenders = int(input("Enter number of Top Recomandation you want see?\n"))
        if __name__ == "__main__":
            print("On My Way...... 🏋️ 💬 W🕛RK🏋️ ING 🕡N🏋️ IT✅")
            res = search_eng.query(user_id=user_id, text=query,to_read_boosting_factor = boosting_factor, K=top_recommenders, save_res=save_res)
            print(res)
            if save_res:
                print("Results saved to local.")
            else:
                print("Complete")

        x = input("enter 1 if you want to add book in to_read list for future perpose's\nenter 2 if you want to add any book into your Favourite List\nenter 3 if you want to see user Favourite list of books\nIf not enter any key😊😊\n")
        if(x=='1'):
            # Open the CSV file in append mode
            with open('/Users/cdmstudent/Desktop/DSC-540 Adv ML/Final Project/ChatBot/PersonalizedBookSearchgoodbooks-10k/to_read.csv', mode='a', newline='') as file:
                writer = csv.writer(file)
                book_id = input("enter book_id: ")
                #user_id = input("enter user_id: ")
                # Create a new row as a list or tuple
                new_row = [user_id,book_id]

                # Write the new row to the CSV file
                writer.writerow(new_row)

        if(x=='2'):
            filename = '/Users/cdmstudent/Desktop/DSC-540 Adv ML/Final Project/ChatBot/PersonalizedBookSearch/goodbooks-10k/favourite.csv'

            # Create a new CSV file with headers for two columns User_Id & Book_Id if it doesn't exist
            if not os.path.isfile(filename):
                with open(filename, mode='w', newline='') as file:
                    writer = csv.writer(file)
                    writer.writerow(['User_Id', 'Book_Id'])  # Write headers for the two columns

            with open(filename, mode='r') as file:
                reader = csv.reader(file)
                book_id = input("enter book_id: ")
                #user_id = input("enter user_id: ")
                i =1
                for row in reader:
                    if user_id in row and book_id in row:
                        print("Entered User_Id had this book in the Favourite List")
                        i = 0
                        break
                    else: continue
            if(i==1):
                # Open the CSV file in append mode
                with open(filename, mode='a', newline='') as file:
                    print("Entered User_Id & Book_Id not in your Favourite List, Now we are going to add into it.") 
                    writer = csv.writer(file)
                    new_row = [user_id,book_id]

                    # Write the new row to the CSV file
                    writer.writerow(new_row)

        if(x=='3'):
            # open the CSV file
            with open('/Users/cdmstudent/Desktop/DSC-540 Adv ML/Final Project/ChatBot/PersonalizedBookSearch/goodbooks-10k/favourite.csv', 'r') as file:

                # create a CSV reader object
                reader = csv.reader(file)

                # read the header row
                header = next(reader)

                # create an empty list to store matching rows
                matching_rows = []

                # get the user input
                entered_value = input('Enter User_Id to search: ')

                # loop through the rows and check for matches
                for row in reader:
                    if entered_value == row[0]:
                        with open('/Users/cdmstudent/Desktop/DSC-540 Adv ML/Final Project/ChatBot/PersonalizedBookSearch/goodbooks-10k/books_cleaned.csv', 'r') as file1:
                            reader1 = csv.reader(file1)
                            header = next(reader1)
                            for row1 in reader1:
                                if row[1] == row1[0]:
                                    matching_rows.append(row1)

            print(pd.DataFrame(matching_rows, columns = ['Book_id','Author','Title','isbn13']))


        else: print("Thank You for using Personalized Book Search Engine")


    if(decision=='2'):
        # open the CSV file
        with open('/Users/cdmstudent/Desktop/DSC-540 Adv ML/Final Project/ChatBot/PersonalizedBookSearch/goodbooks-10k/to_read.csv', 'r') as file:

            # create a CSV reader object
            reader = csv.reader(file)

            # read the header row
            header = next(reader)

            # create an empty list to store matching rows
            matching_rows = []

            # get the user input
            entered_value = input('Enter User_id to search: ')

            # loop through the rows and check for matches
            for row in reader:
                if entered_value == row[0]:

                    with open('/Users/cdmstudent/Desktop/DSC-540 Adv ML/Final Project/ChatBot/PersonalizedBookSearch/goodbooks-10k/books_cleaned.csv', 'r') as file1:
                        reader1 = csv.reader(file1)
                        header = next(reader1)
                        for row1 in reader1:
                            if row[1] == row1[0]:
                                matching_rows.append(row1)

        print(pd.DataFrame(matching_rows, columns = ['Book_id','Author','Title','isbn13']))
        print("\nPick anyone one book and enjoy your reading with whishlist books")

    if(decision!='2' and decision !='1'and decision== True): print("Typo error, please type 1 or 2 according to your plan\nThank you😊😊")

# %%
main()
# Out:
# Welcom to Personalized Book Search Engine
#
#
# Enter 1 if you want to proceed to Book Search to find similar books
# Enter 2 if you want to continue with books in your wishlist/to_read
# 2
# Enter User_id to search: 37
#   Book_id                                             Author  \
# 0    7173  Eiji Yoshikawa, Charles Terry, Edwin O. Reisch...
# 1    3384                                     R.L. Mathewson
# 2     346                        L. Frank Baum, W.W. Denslow
# 3     819                                Henry David Thoreau
# 4    1000                                      Leigh Bardugo
#
#                           Title           isbn13
# 0         宮本武蔵 Miyamoto Musashi  9784770019580.0
# 1                    Perfection  9780983212550.0
# 2    The Wonderful Wizard of Oz  9780140621680.0
# 3  Walden; or Life in the Woods  9780691096120.0
# 4               Shadow and Bone  9780805094600.0
#
# Pick anyone one book and enjoy your reading with whishlist books

# %%
main()
# Out:
# Welcom to Personalized Book Search Engine
#
#
# Enter 1 if you want to proceed to Book Search to find similar books
# Enter 2 if you want to continue with books in your wishlist/to_read
# 1
# Enter User_Id between 0-53424
# 1009
# Enter your text/query to find similar recommadtions to it.
# seas
# Enter to_read_boosting_factor ? :
# 1.6
# Enter number of Top Recomandation you want see?
# 20
# On My Way...... 🏋️ 💬 W🕛RK🏋️ ING 🕡N🏋️ IT✅
#     book_id                           authors  \
# 0      5556                     John Banville
# 1      8508         Iris Murdoch, Mary Kinzie
# 2      7274      Margaret Weis, Tracy Hickman
# 3      3228                      Ruta Sepetys
# 4      2476  Susanna Kearsley, Rosalyn Landor
# 5      1254                       Scott Lynch
# 6      3122             Anne Morrow Lindbergh
# 7      1514               Nathaniel Philbrick
# 8      1366                       Rick Yancey
# 9      2159                      Nora Roberts
# 10     1591                 Ursula K. Le Guin
# 11      130                  Ernest Hemingway
# 12      289                     Richard Adams
# 13     5748                      Nora Roberts
# 14     5382                       Jack London
# 15     3739                 Madeleine L'Engle
# 16     4571                    Steven Erikson
# 17     8009                  Iris Rainer Dart
# 18      277                       Neil Gaiman
# 19      151                      Rick Riordan
#
#                                                 title        isbn13  \
# 0                                             The Sea  9.781400e+12
# 1                                    The Sea, the Sea  9.780141e+12
# 2                                            Fire Sea  9.780553e+12
# 3                                     Salt to the Sea  9.780399e+12
# 4                                      The Winter Sea  9.780749e+12
# 5                            Red Seas Under Red Skies  9.780554e+12
# 6                                   Gift from the Sea  9.780395e+12
# 7   In the Heart of the Sea: The Tragedy of the Wh...  9.780141e+12
# 8                                    The Infinite Sea           NaN
# 9                                           Sea Swept  9.780515e+12
# 10                                 The Farthest Shore  9.781417e+12
# 11                            The Old Man and the Sea  9.780685e+12
# 12                                     Watership Down  9.780380e+12
# 13                                   Heart of the Sea  9.780515e+12
# 14                                       The Sea Wolf  9.781598e+12
# 15                                        Many Waters  9.780312e+12
# 16                                     Midnight Tides  9.780554e+12
# 17                                            Beaches  9.780061e+12
# 18                   The Ocean at the End of the Lane  9.780062e+12
# 19                                The Sea of Monsters  9.780787e+12
#
#     in_to_read_list  final_score
# 0              True     5.531986
# 1             False     3.546860
# 2             False     3.147733
# 3             False     3.089912
# 4             False     2.976257
# 5             False     2.957174
# 6             False     2.880623
# 7             False     2.842301
# 8             False     2.676030
# 9             False     2.596344
# 10            False     2.563469
# 11            False     2.541626
# 12            False     2.535471
# 13            False     2.509778
# 14            False     2.495037
# 15            False     2.487742
# 16            False     2.471514
# 17            False     2.468349
# 18            False     2.457325
# 19            False     2.456561
# Results saved to local.
# enter 1 if you want to add book in to_read list for future perpose's
# enter 2 if you want to add any book into your Favourite List
# enter 3 if you want to see user Favourite list of books
# If not enter any key😊😊
# 1
# enter book_id: 8508
# enter user_id: 1009
# Thank You for using Personalized Book Search Engine

# %%
main()
# Out:
# Welcom to Personalized Book Search Engine
#
#
# Enter 1 if you want to proceed to Book Search to find similar books
# Enter 2 if you want to continue with books in your wishlist/to_read
# 1
# Enter User_Id between 0-53424
# 1009
# Enter your text/query to find similar recommadtions to it.
# seas
# Enter to_read_boosting_factor ? :
# 1.5
# Enter number of Top Recomandation you want see?
# 20
# On My Way...... 🏋️ 💬 W🕛RK🏋️ ING 🕡N🏋️ IT✅
#     book_id                           authors  \
# 0      8508         Iris Murdoch, Mary Kinzie
# 1      5556                     John Banville
# 2      7274      Margaret Weis, Tracy Hickman
# 3      3228                      Ruta Sepetys
# 4      2476  Susanna Kearsley, Rosalyn Landor
# 5      1254                       Scott Lynch
# 6      3122             Anne Morrow Lindbergh
# 7      1514               Nathaniel Philbrick
# 8      1366                       Rick Yancey
# 9      2159                      Nora Roberts
# 10     1591                 Ursula K. Le Guin
# 11      130                  Ernest Hemingway
# 12      289                     Richard Adams
# 13     5748                      Nora Roberts
# 14     5382                       Jack London
# 15     3739                 Madeleine L'Engle
# 16     4571                    Steven Erikson
# 17     8009                  Iris Rainer Dart
# 18      277                       Neil Gaiman
# 19      151                      Rick Riordan
#
#                                                 title        isbn13  \
# 0                                    The Sea, the Sea  9.780141e+12
# 1                                             The Sea  9.781400e+12
# 2                                            Fire Sea  9.780553e+12
# 3                                     Salt to the Sea  9.780399e+12
# 4                                      The Winter Sea  9.780749e+12
# 5                            Red Seas Under Red Skies  9.780554e+12
# 6                                   Gift from the Sea  9.780395e+12
# 7   In the Heart of the Sea: The Tragedy of the Wh...  9.780141e+12
# 8                                    The Infinite Sea           NaN
# 9                                           Sea Swept  9.780515e+12
# 10                                 The Farthest Shore  9.781417e+12
# 11                            The Old Man and the Sea  9.780685e+12
# 12                                     Watership Down  9.780380e+12
# 13                                   Heart of the Sea  9.780515e+12
# 14                                       The Sea Wolf  9.781598e+12
# 15                                        Many Waters  9.780312e+12
# 16                                     Midnight Tides  9.780554e+12
# 17                                            Beaches  9.780061e+12
# 18                   The Ocean at the End of the Lane  9.780062e+12
# 19                                The Sea of Monsters  9.780787e+12
#
#     in_to_read_list  final_score
# 0              True     5.320290
# 1              True     5.186237
# 2             False     3.147733
# 3             False     3.089912
# 4             False     2.976257
# 5             False     2.957174
# 6             False     2.880623
# 7             False     2.842301
# 8             False     2.676030
# 9             False     2.596344
# 10            False     2.563469
# 11            False     2.541626
# 12            False     2.535471
# 13            False     2.509778
# 14            False     2.495037
# 15            False     2.487742
# 16            False     2.471514
# 17            False     2.468349
# 18            False     2.457325
# 19            False     2.456561
# Results saved to local.
# enter 1 if you want to add book in to_read list for future perpose's
# enter 2 if you want to add any book into your Favourite List
# enter 3 if you want to see user Favourite list of books
# If not enter any key😊😊
# 2
# enter book_id: 7274
# Entered User_Id & Book_Id not in your Favourite List, Now we are going to add into it.
# Thank You for using Personalized Book Search Engine

# %%
main()
# Out:
# Welcom to Personalized Book Search Engine
#
#
# Enter 1 if you want to proceed to Book Search to find similar books
# Enter 2 if you want to continue with books in your wishlist/to_read
# 1
# Enter User_Id between 0-53424
# 1009
# Enter your text/query to find similar recommadtions to it.
# seassss
# Enter to_read_boosting_factor ? :
# 1.5
# Enter number of Top Recomandation you want see?
# 20
# On My Way...... 🏋️ 💬 W🕛RK🏋️ ING 🕡N🏋️ IT✅
#     book_id                                       authors  \
# 0      8508                     Iris Murdoch, Mary Kinzie
# 1      5556                                 John Banville
# 2       767                             Laura Hillenbrand
# 3      7274                  Margaret Weis, Tracy Hickman
# 4       289                                 Richard Adams
# 5      3122                         Anne Morrow Lindbergh
# 6      2476              Susanna Kearsley, Rosalyn Landor
# 7      1514                           Nathaniel Philbrick
# 8      3228                                  Ruta Sepetys
# 9      1254                                   Scott Lynch
# 10     6769                       J.J. Abrams, Doug Dorst
# 11     9636                                  Nancy Farmer
# 12     6571                                 John Flanagan
# 13     2159                                  Nora Roberts
# 14      151                                  Rick Riordan
# 15     5625                                  Sarah Vowell
# 16     8009                              Iris Rainer Dart
# 17     7343  John Lawrence Peterson, Roberta Carter Clark
# 18     5382                                   Jack London
# 19     9561                   Nikolai Gogol, Kevin Hawkes
#
#                                                 title        isbn13  \
# 0                                    The Sea, the Sea  9.780141e+12
# 1                                             The Sea  9.781400e+12
# 2                                          Seabiscuit  9.780345e+12
# 3                                            Fire Sea  9.780553e+12
# 4                                      Watership Down  9.780380e+12
# 5                                   Gift from the Sea  9.780395e+12
# 6                                      The Winter Sea  9.780749e+12
# 7   In the Heart of the Sea: The Tragedy of the Wh...  9.780141e+12
# 8                                     Salt to the Sea  9.780399e+12
# 9                            Red Seas Under Red Skies  9.780554e+12
# 10                                                 S.  9.780316e+12
# 11                                  The Sea of Trolls  9.780690e+12
# 12                                       The Outcasts  9.780399e+12
# 13                                          Sea Swept  9.780515e+12
# 14                                The Sea of Monsters  9.780787e+12
# 15                                The Wordy Shipmates  9.781594e+12
# 16                                            Beaches  9.780061e+12
# 17                                        The Littles  9.780590e+12
# 18                                       The Sea Wolf  9.781598e+12
# 19                                                Нос  9.780688e+12
#
#     in_to_read_list  final_score
# 0              True     3.607186
# 1              True     3.413813
# 2             False     2.321383
# 3             False     2.212985
# 4             False     2.182334
# 5             False     2.109121
# 6             False     2.106362
# 7             False     2.091826
# 8             False     2.085867
# 9             False     2.066380
# 10            False     2.013997
# 11            False     1.981438
# 12            False     1.944315
# 13            False     1.926677
# 14            False     1.924829
# 15            False     1.893394
# 16            False     1.870247
# 17            False     1.856071
# 18            False     1.849474
# 19            False     1.844213
# Results saved to local.
# enter 1 if you want to add book in to_read list for future perpose's
# enter 2 if you want to add any book into your Favourite List
# enter 3 if you want to see user Favourite list of books
# If not enter any key😊😊
# 3
# Enter User_Id to search: 1009
#   Book_id                          Author  \
# 0    3708  Banana Yoshimoto, Megan Backus
# 1    8362                 Matthew Desmond
# 2    8508       Iris Murdoch, Mary Kinzie
# 3    7274    Margaret Weis, Tracy Hickman
#
#                                               Title           isbn13
# 0                                    キッチン [Kitchen]  9780802142440.0
# 1  Evicted: Poverty and Profit in the American City  9780553447440.0
# 2                                  The Sea, the Sea  9780141186160.0
# 3                                          Fire Sea  9780553295410.0
